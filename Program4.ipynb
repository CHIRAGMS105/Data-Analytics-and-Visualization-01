# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\user\Downloads\synthetic_dataset.csv")
print(data.isnull())
# Out:
#       Category  Price  Rating  Stock  Discount
# 0         True  False   False   True     False
# 1         True  False   False   True     False
# 2         True  False    True  False     False
# 3         True  False   False   True     False
# 4         True  False    True  False     False
# ...        ...    ...     ...    ...       ...
# 4357      True  False   False   True     False
# 4358     False  False    True  False     False
# 4359      True  False    True  False     False
# 4360     False  False   False   True     False
# 4361      True   True   False   True     False
#
# [4362 rows x 5 columns]

# %%
print(data.isnull().sum())
# Out:
# Category    2748
# Price        174
# Rating      2050
# Stock       1352
# Discount     392
# dtype: int64

# %%
data['Rating']=data['Rating'].fillna(data['Rating'].mean())
print(data)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0  3.038293      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0  3.038293  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0  3.038293  Out of Stock       4.0
# 4359      NaN  3283.0  3.038293  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
print("Mean Price:", data['Price'].mean())
# Out:
# Mean Price: 5016.970630372492

# %%
data['Rating'] = data['Rating'].fillna(data['Rating'].median())
print(data)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0  3.038293      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0  3.038293  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357      NaN  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0  3.038293  Out of Stock       4.0
# 4359      NaN  3283.0  3.038293  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361      NaN     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
data['Category'] = data['Category'].ffill()
print(data)
# Out:
#      Category   Price    Rating         Stock  Discount
# 0         NaN  5548.0  1.870322           NaN       0.0
# 1         NaN  3045.0  4.757798           NaN      38.0
# 2         NaN  4004.0  3.038293      In Stock       0.0
# 3         NaN  4808.0  1.492085           NaN      33.0
# 4         NaN  1817.0  3.038293  Out of Stock      23.0
# ...       ...     ...       ...           ...       ...
# 4357        B  4436.0  4.728335           NaN      49.0
# 4358        B  6236.0  3.038293  Out of Stock       4.0
# 4359        B  3283.0  3.038293  Out of Stock       9.0
# 4360        D  2999.0  4.425995           NaN      40.0
# 4361        D     NaN  2.184471           NaN       0.0
#
# [4362 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['Category_Encoded'] = encoder.fit_transform(data['Category'])
print(data)
print(encoder.classes_)
# Out:
#      Category   Price    Rating         Stock  Discount  Category_Encoded
# 0         NaN  5548.0  1.870322           NaN       0.0                 4
# 1         NaN  3045.0  4.757798           NaN      38.0                 4
# 2         NaN  4004.0  3.038293      In Stock       0.0                 4
# 3         NaN  4808.0  1.492085           NaN      33.0                 4
# 4         NaN  1817.0  3.038293  Out of Stock      23.0                 4
# ...       ...     ...       ...           ...       ...               ...
# 4357        B  4436.0  4.728335           NaN      49.0                 1
# 4358        B  6236.0  3.038293  Out of Stock       4.0                 1
# 4359        B  3283.0  3.038293  Out of Stock       9.0                 1
# 4360        D  2999.0  4.425995           NaN      40.0                 3
# 4361        D     NaN  2.184471           NaN       0.0                 3
#
# [4362 rows x 6 columns]
# ['A' 'B' 'C' 'D' nan]

# %%
data = pd.get_dummies(data, columns=['Category'])
print(data)
# Out:
#        Price    Rating         Stock  Discount  Category_Encoded  Category_A  \
# 0     5548.0  1.870322           NaN       0.0                 4           0
# 1     3045.0  4.757798           NaN      38.0                 4           0
# 2     4004.0  3.038293      In Stock       0.0                 4           0
# 3     4808.0  1.492085           NaN      33.0                 4           0
# 4     1817.0  3.038293  Out of Stock      23.0                 4           0
# ...      ...       ...           ...       ...               ...         ...
# 4357  4436.0  4.728335           NaN      49.0                 1           0
# 4358  6236.0  3.038293  Out of Stock       4.0                 1           0
# 4359  3283.0  3.038293  Out of Stock       9.0                 1           0
# 4360  2999.0  4.425995           NaN      40.0                 3           0
# 4361     NaN  2.184471           NaN       0.0                 3           0
#
#       Category_B  Category_C  Category_D
# ...

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\synthetic_dataset.csv")
data = pd.get_dummies(data, columns=['Category'], dtype=int)
print(data)
# Out:
#        Price    Rating         Stock  Discount  Category_A  Category_B  \
# 0     5548.0  1.870322           NaN       0.0           0           0
# 1     3045.0  4.757798           NaN      38.0           0           0
# 2     4004.0       NaN      In Stock       0.0           0           0
# 3     4808.0  1.492085           NaN      33.0           0           0
# 4     1817.0       NaN  Out of Stock      23.0           0           0
# ...      ...       ...           ...       ...         ...         ...
# 4357  4436.0  4.728335           NaN      49.0           0           0
# 4358  6236.0       NaN  Out of Stock       4.0           0           1
# 4359  3283.0       NaN  Out of Stock       9.0           0           0
# 4360  2999.0  4.425995           NaN      40.0           0           0
# 4361     NaN  2.184471           NaN       0.0           0           0
#
#       Category_C  Category_D
# 0              0           0
# 1              0           0
# ...

# %%
print(data)
# Out:
#        Price    Rating         Stock  Discount  Category_A  Category_B  \
# 0     5548.0  1.870322           NaN       0.0           0           0
# 1     3045.0  4.757798           NaN      38.0           0           0
# 2     4004.0       NaN      In Stock       0.0           0           0
# 3     4808.0  1.492085           NaN      33.0           0           0
# 4     1817.0       NaN  Out of Stock      23.0           0           0
# ...      ...       ...           ...       ...         ...         ...
# 4357  4436.0  4.728335           NaN      49.0           0           0
# 4358  6236.0       NaN  Out of Stock       4.0           0           1
# 4359  3283.0       NaN  Out of Stock       9.0           0           0
# 4360  2999.0  4.425995           NaN      40.0           0           0
# 4361     NaN  2.184471           NaN       0.0           0           0
#
#       Category_C  Category_D
# 0              0           0
# 1              0           0
# ...
